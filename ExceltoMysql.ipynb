# %%
import pandas as pd
import numpy as np
import pymysql
from sqlalchemy import create_engine

# %%
df=pd.ExcelFile('input_pkmn_stats_and_evolutions.xlsx')
df_pks=df.parse(0)
df_pke=df.parse(1)

# %%
pd.options.display.max_rows=None
df_pks
# Out:
#                  name  pokedex_number  gen_introduced   hp  attack  defense  \
# 0           Bulbasaur               1               1   45      49       49
# 1             Ivysaur               2               1   60      62       63
# 2            Venusaur               3               1   80      82       83
# 3          Charmander               4               1   39      52       43
# 4          Charmeleon               5               1   58      64       58
# 5           Charizard               6               1   78      84       78
# 6            Squirtle               7               1   44      48       65
# 7           Wartortle               8               1   59      63       80
# 8           Blastoise               9               1   79      83      100
# 9            Caterpie              10               1   45      30       35
# 10            Metapod              11               1   50      20       55
# ...

# %%
# to sql
eng=create_engine('mysql+pymysql://root:yxdj87212241@localhost/pokemon_evolution_stats')
df_pks.to_sql('pks',eng, index=False, if_exists='replace')
df_pke.to_sql('pke',eng, index=False, if_exists='replace')
